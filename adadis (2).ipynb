# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_excel('C:\\Users\\exam2\\Downloads\\Adidas_US_Sales_Datasets_1_.xlsx')
dataset
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %% [markdown]
# 1.	List all the retailers with retailer id.

# %%
dataset.groupby(['Retailer','Retailer ID'])['Retailer'].apply(list)
# Out:
# Retailer       Retailer ID
# Amazon         1185732        [Amazon, Amazon, Amazon, Amazon, Amazon, Amazo...
# Foot Locker    1128299        [Foot Locker, Foot Locker, Foot Locker, Foot L...
#                1185732        [Foot Locker, Foot Locker, Foot Locker, Foot L...
#                1197831        [Foot Locker, Foot Locker, Foot Locker, Foot L...
# Kohl's         1128299        [Kohl's, Kohl's, Kohl's, Kohl's, Kohl's, Kohl'...
#                1185732        [Kohl's, Kohl's, Kohl's, Kohl's, Kohl's, Kohl'...
#                1189833        [Kohl's, Kohl's, Kohl's, Kohl's, Kohl's, Kohl'...
#                1197831        [Kohl's, Kohl's, Kohl's, Kohl's, Kohl's, Kohl'...
# Sports Direct  1128299        [Sports Direct, Sports Direct, Sports Direct, ...
#                1185732        [Sports Direct, Sports Direct, Sports Direct, ...
#                1197831        [Sports Direct, Sports Direct, Sports Direct, ...
# ...

# %% [markdown]
# 2.	List all the retailers in every region.

# %%
dataset.groupby('Retailer')['Region'].apply(list)
# Out:
# Retailer
# Amazon           [South, South, South, South, Northeast, Northe...
# Foot Locker      [Northeast, Northeast, Northeast, Northeast, N...
# Kohl's           [West, West, West, West, West, West, West, Wes...
# Sports Direct    [Northeast, Northeast, Northeast, Northeast, S...
# Walmart          [Northeast, Northeast, Northeast, Northeast, N...
# West Gear        [South, South, South, South, West, West, West,...
# Name: Region, dtype: object

# %% [markdown]
# 3.	List the retailers in every city of a state.

# %%
dataset.groupby(['City','State'])['Retailer'].apply(list)
# Out:
# City            State
# Albany          New York          [West Gear, West Gear, West Gear, West Gear, W...
# Albuquerque     New Mexico        [Kohl's, Kohl's, Kohl's, Kohl's, Kohl's, Kohl'...
# Anchorage       Alaska            [Amazon, Amazon, Amazon, Amazon, Amazon, Amazo...
# Atlanta         Georgia           [Sports Direct, Sports Direct, Sports Direct, ...
# Baltimore       Maryland          [West Gear, West Gear, West Gear, West Gear, W...
# Billings        Montana           [Kohl's, Kohl's, Kohl's, Kohl's, Kohl's, Kohl'...
# Birmingham      Alabama           [Sports Direct, Sports Direct, Sports Direct, ...
# Boise           Idaho             [Foot Locker, Foot Locker, Foot Locker, Foot L...
# Boston          Massachusetts     [Sports Direct, Sports Direct, Sports Direct, ...
# Burlington      Vermont           [Amazon, Amazon, Amazon, Amazon, Amazon, Amazo...
# Charleston      South Carolina    [Foot Locker, Foot Locker, Foot Locker, Foot L...
# ...

# %% [markdown]
# 4.	List the products sold by the retailer in every city.

# %%
dataset.groupby(['Retailer','City'])['Product'].apply(list)
# Out:
# Retailer   City
# Amazon     Anchorage         [Women's Apparel, Men's Street Footwear, Men's...
#            Birmingham        [Men's Street Footwear, Men's Athletic Footwea...
#            Boston            [Women's Apparel, Men's Street Footwear, Men's...
#            Burlington        [Women's Athletic Footwear, Men's Apparel, Wom...
#            Charlotte         [Women's Street Footwear, Women's Athletic Foo...
#                                                    ...
# West Gear  Portland          [Men's Street Footwear, Men's Athletic Footwea...
#            Salt Lake City    [Women's Athletic Footwear, Men's Apparel, Wom...
#            San Francisco     [Men's Apparel, Women's Apparel, Men's Street ...
#            Seattle           [Men's Apparel, Women's Apparel, Men's Street ...
#            St. Louis         [Women's Street Footwear, Women's Athletic Foo...
# Name: Product, Length: 108, dtype: object

# %% [markdown]
# 5.	Find the total sales of every retailer.

# %%
dataset.groupby('Retailer').sum('Total Sales')['Total Sales']
# Out:
# Retailer
# Amazon            77698912.0
# Foot Locker      220094720.0
# Kohl's           102114753.0
# Sports Direct    182470997.0
# Walmart           74558410.0
# West Gear        242964333.0
# Name: Total Sales, dtype: float64

# %% [markdown]
# 6.	Find the total sales of the retailers in every city along with profit.

# %%
dataset.groupby(['Retailer','City']).sum(['Total Sales','Operating Margin'])[['Total Sales','Operating Profit']]
# Out:
#                           Total Sales  Operating Profit
# Retailer  City
# Amazon    Anchorage        13365025.0        4143804.75
#           Birmingham         409091.0         146947.48
#           Boston            4193590.0        1375377.31
#           Burlington       13380463.0        5376161.02
#           Charlotte         3733676.0        1532481.72
# ...                               ...               ...
# West Gear Portland         21934257.0        7712540.80
#           Salt Lake City    9696420.0        3873429.10
#           San Francisco    33360397.0        9843005.12
#           Seattle          24862675.0        6469771.84
#           St. Louis         1701133.0         681457.25
#
# [108 rows x 2 columns]

# %% [markdown]
# 7.	Find the total sales &profit of each product sold by the retailer.

# %%
dataset.groupby(['Product','Retailer']).sum(['Total Sales','Operating Profit'])[['Total Sales','Operating Profit']].apply(list)
# dataset
# Out:
#                                          Total Sales  Operating Profit
# Product                   Retailer
# Men's Apparel             Amazon          10474770.0        3331443.80
#                           Foot Locker     29508995.0        9942404.61
#                           Kohl's          14164965.0        5945043.20
#                           Sports Direct   24825286.0        8723914.71
#                           Walmart         11490680.0        3166591.22
#                           West Gear       33263936.0       13653632.79
# Men's Athletic Footwear   Amazon          12011959.0        4518030.11
#                           Foot Locker     36480415.0       12409221.49
#                           Kohl's          17885316.0        5725762.60
#                           Sports Direct   30889734.0       11935672.81
#                           Walmart         13600404.0        4029257.65
#                           West Gear       42805852.0       13228943.53
# ...

# %% [markdown]
# 8.	Find the units sold, total sales &profit of the products sold between the dates 1/1/2020 and 4/15/2020.

# %%
dataset[dataset['Invoice Date'].between('2020-01-01','2020-04-05')][['Units Sold','Total Sales','Operating Profit']]
# Out:
#       Units Sold  Total Sales  Operating Profit
# 0           1200     600000.0         300000.00
# 1           1000     500000.0         150000.00
# 2           1000     400000.0         140000.00
# 3            850     382500.0         133875.00
# 4            900     540000.0         162000.00
# ...          ...          ...               ...
# 8275         170       9520.0           1713.60
# 8276         149       2980.0           1192.00
# 8277         145       4495.0           1123.75
# 8278         128       3328.0           1397.76
# 8279          96       2496.0            848.64
#
# [405 rows x 3 columns]

# %% [markdown]
# 9.	Find the no of units sold of each product by each retailer in every city.

# %%
dataset.groupby(['Product','Retailer','City']).sum('Units Sold')['Units Sold']
# Out:
# Product                  Retailer   City
# Men's Apparel            Amazon     Anchorage          2990
#                                     Boston             1235
#                                     Burlington         4607
#                                     Charlotte          1447
#                                     Columbus           6054
#                                                       ...
# Women's Street Footwear  West Gear  Portland           9168
#                                     Salt Lake City     7303
#                                     San Francisco     13346
#                                     Seattle            6888
#                                     St. Louis          1678
# Name: Units Sold, Length: 618, dtype: int64

# %% [markdown]
# 10.	Find the products with different price per unit in different cities with proper information.

# %%
dataset.groupby(['Product','City'])['Price per Unit'].first()
# Out:
# Product                  City
# Men's Apparel            Albany         55.0
#                          Albuquerque    50.0
#                          Anchorage      65.0
#                          Atlanta        45.0
#                          Baltimore      45.0
#                                         ...
# Women's Street Footwear  Seattle        50.0
#                          Sioux Falls    30.0
#                          St. Louis      25.0
#                          Wichita        10.0
#                          Wilmington     30.0
# Name: Price per Unit, Length: 312, dtype: float64

# %% [markdown]
# 11.	Find the total sales &profits of all products in every month.

# %%
dataset.groupby([pd.Grouper(key='Invoice Date',axis=0,freq='M'),'Product'])['Total Sales','Operating Profit'].sum()
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
dataset.groupby([pd.Grouper(key='Invoice Date',axis=0,freq='M'),'Product'])['Total Sales','Operating Profit'].sum()
# Out:
# C:\Users\exam2\AppData\Local\Temp/ipykernel_8888/1703652395.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dataset.groupby([pd.Grouper(key='Invoice Date',axis=0,freq='M'),'Product'])['Total Sales','Operating Profit'].sum()
#                                         Total Sales  Operating Profit
# Invoice Date Product
# 2020-01-31   Men's Apparel                2288362.0         857217.30
#              Men's Athletic Footwear      2639958.0         759529.03
#              Men's Street Footwear        3859495.0        1829393.59
#              Women's Apparel              3066713.0         743644.58
#              Women's Athletic Footwear    1990181.0         714155.67
# ...                                             ...               ...
# 2021-12-31   Men's Athletic Footwear     13195038.0        4656590.45
#              Men's Street Footwear       18953848.0        7535532.29
# ...

# %% [markdown]
# 12.	Find the total sales &profit of the products in different sales methods in each city.

# %%
dataset.groupby(['Sales Method','City']).sum(['Total Sales','Operating Profit'])[['Total Sales','Operating Profit']]
# Out:
#                              Total Sales  Operating Profit
# Sales Method City
# In-store     Albany           23815000.0        9121062.50
#              Baltimore         7563250.0        2664612.50
#              Boston           10553750.0        3151637.50
#              Burlington       13679250.0        5456525.00
#              Charleston       10420000.0        4142250.00
# ...                                  ...               ...
# Outlet       Portland          9445482.0        3270671.47
#              Providence         190686.0          76759.23
#              Richmond           485229.0         193031.55
#              Salt Lake City     224438.0          99384.57
#              San Francisco    33680352.0        9900805.90
#
# [112 rows x 2 columns]

# %% [markdown]
# 13.	Find the retailers who sold the same product with different prices in different cities.

# %%
dataset.groupby(['Retailer','Product','City','Price per Unit'])['Retailer'].apply(list)
# dataset
# Out:
# Retailer   Product                  City       Price per Unit
# Amazon     Men's Apparel            Anchorage  56.0                              [Amazon]
#                                                60.0                      [Amazon, Amazon]
#                                                60.0                              [Amazon]
#                                                61.0                              [Amazon]
#                                                62.0              [Amazon, Amazon, Amazon]
#                                                                            ...
# West Gear  Women's Street Footwear  Seattle    85.0                           [West Gear]
#                                     St. Louis  14.0                [West Gear, West Gear]
#                                                15.0                [West Gear, West Gear]
#                                                32.0                           [West Gear]
# ...

# %% [markdown]
# 14.	Find the products whose sales raises in every month.

# %%
dataset.groupby(['Product',pd.Grouper(key='Invoice Date',axis=0,freq='M')])['Total Sales'].sum().diff().apply(lambda x: x>0)
# Out:
# Product                  Invoice Date
# Men's Apparel            2020-01-31      False
#                          2020-02-29      False
#                          2020-03-31      False
#                          2020-04-30       True
#                          2020-05-31      False
#                                          ...
# Women's Street Footwear  2021-08-31       True
#                          2021-09-30      False
#                          2021-10-31      False
#                          2021-11-30       True
#                          2021-12-31       True
# Name: Total Sales, Length: 144, dtype: bool

# %% [markdown]
# 15.	Find the retailers whose profit increased every month.

# %%
dataset.groupby(['Retailer',pd.Grouper(key='Invoice Date',axis=0,freq='M')]).sum(['Operating Profit'])['Operating Profit'].diff().apply(lambda x:x>0)
# Out:
# Retailer   Invoice Date
# Amazon     2021-01-31      False
#            2021-02-28       True
#            2021-03-31      False
#            2021-04-30      False
#            2021-05-31       True
#                            ...
# West Gear  2021-08-31      False
#            2021-09-30      False
#            2021-10-31       True
#            2021-11-30       True
#            2021-12-31       True
# Name: Operating Profit, Length: 104, dtype: bool

# %%
dataset
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...
